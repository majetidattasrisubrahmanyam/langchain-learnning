# %% [markdown]
# Data ingestion

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is context file written by subbu for learning of RAG for the first time",
    metadata = {
        "source" : "example.txt",
        "author" : "subbu",
        "pages" : 1,
        "datecreated" :"25-06-2026"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'author': 'subbu', 'pages': 1, 'datecreated': '25-06-2026'}, page_content='This is context file written by subbu for learning of RAG for the first time')

# %%
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
##text loader
##from langchain.document_loaders import TextLoader
from langchain_community.document_loaders import TextLoader
from langchain_community.document_loaders import DirectoryLoader
loader = TextLoader("../data/text_files/machienlearning.txt",encoding = "utf-8")
document =  loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/machienlearning.txt'}, page_content='Machine Learning (ML) is a branch of Artificial Intelligence (AI) that enables computers to learn patterns from data and make predictions or decisions without being explicitly programmed for every task.\nBasic ML Workflow:\n\nCollect Data\nClean and Prepare Data\nTrain a Model\nTest the Model\nMake Predictions\n\nExample:\n\nInput: Previous house prices and features\nML Model learns patterns\nOutput: Predicts the price of a new house\n\nCommon Applications:\n\nRecommendation systems (Netflix, YouTube)\nSpam email detection\nFace recognition\nChatbots and LLMs\nFraud detection')]

# %%
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader
dir_loader = DirectoryLoader(
    "../data/text_files/pdf",
    glob = "**/*.pdf",
    loader_cls = PyMuPDFLoader,
    show_progress = False
)

pdf_documents = dir_loader.load()
pdf_documents
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 9
#       5     loader_cls = PyMuPDFLoader,
#       6     show_progress = False
#       7 )
#       8
# ----> 9 pdf_documents = dir_loader.load()
#      10 pdf_documents
#
# File c:\Users\subra\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_community\document_loaders\directory.py:117, in DirectoryLoader.load(self)
#     115 def load(self) -> List[Document]:
#     116     """Load documents."""
# --> 117     return list(self.lazy_load())
#
# File c:\Users\subra\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_community\document_loaders\directory.py:123, in DirectoryLoader.lazy_load(self)
#     121 p = Path(self.path)
#     122 if not p.exists():
# --> 123     raise FileNotFoundError(f"Directory not found: '{self.path}'")
#     124 if not p.is_dir():
#     125     raise ValueError(f"Expected directory, got file: '{self.path}'")
#
# esearch.pdf'
